# %% [markdown]
# # LSTM:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# fix random seed for reproducibility
tf.random.set_seed(33)

# %%
import pandas
import matplotlib.pyplot as plt


dataset = pandas.read_csv('airline-passengers.csv', usecols=[1])
plt.plot(dataset)
plt.show()

# %%
dataset = pd.DataFrame(dataset)
dataset.head()
# Out:
#           0
# 0  0.015444
# 1  0.027027
# 2  0.054054
# 3  0.048263
# 4  0.032819

# %%
dataset.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
dataset.shape
# Out:
# (144, 1)

# %%
dataset = dataset.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset with MinMax normalization

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size


train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 115 29

# %%
train.shape
# Out:
# (115, 1)

# %%
test.shape
# Out:
# (29, 1)

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
  return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX.shape
# Out:
# (113, 1)

# %%
trainX[0]
# Out:
# array([0.01544401], dtype=float32)

# %%
trainX.shape[1]
# Out:
# 1

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))

model.add(Dense(1))


model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 113/113 - 2s - loss: 0.0375 - 2s/epoch - 17ms/step
# Epoch 2/100
# 113/113 - 0s - loss: 0.0150 - 186ms/epoch - 2ms/step
# Epoch 3/100
# 113/113 - 0s - loss: 0.0119 - 177ms/epoch - 2ms/step
# Epoch 4/100
# 113/113 - 0s - loss: 0.0104 - 185ms/epoch - 2ms/step
# Epoch 5/100
# 113/113 - 0s - loss: 0.0089 - 176ms/epoch - 2ms/step
# Epoch 6/100
# 113/113 - 0s - loss: 0.0074 - 181ms/epoch - 2ms/step
# Epoch 7/100
# 113/113 - 0s - loss: 0.0063 - 181ms/epoch - 2ms/step
# Epoch 8/100
# 113/113 - 0s - loss: 0.0051 - 190ms/epoch - 2ms/step
# Epoch 9/100
# 113/113 - 0s - loss: 0.0044 - 183ms/epoch - 2ms/step
# Epoch 10/100
# 113/113 - 0s - loss: 0.0038 - 178ms/epoch - 2ms/step
# Epoch 11/100
# 113/113 - 0s - loss: 0.0034 - 183ms/epoch - 2ms/step
# Epoch 12/100
# 113/113 - 0s - loss: 0.0031 - 180ms/epoch - 2ms/step
# Epoch 13/100
# 113/113 - 0s - loss: 0.0030 - 184ms/epoch - 2ms/step
# Epoch 14/100
# 113/113 - 0s - loss: 0.0028 - 180ms/epoch - 2ms/step
# Epoch 15/100
# 113/113 - 0s - loss: 0.0028 - 182ms/epoch - 2ms/step
# Epoch 16/100
# 113/113 - 0s - loss: 0.0029 - 173ms/epoch - 2ms/step
# Epoch 17/100
# 113/113 - 0s - loss: 0.0027 - 175ms/epoch - 2ms/step
# Epoch 18/100
# 113/113 - 0s - loss: 0.0027 - 177ms/epoch - 2ms/step
# Epoch 19/100
# 113/113 - 0s - loss: 0.0027 - 190ms/epoch - 2ms/step
# Epoch 20/100
# 113/113 - 0s - loss: 0.0027 - 180ms/epoch - 2ms/step
# Epoch 21/100
# 113/113 - 0s - loss: 0.0028 - 175ms/epoch - 2ms/step
# Epoch 22/100
# 113/113 - 0s - loss: 0.0027 - 183ms/epoch - 2ms/step
# Epoch 23/100
# 113/113 - 0s - loss: 0.0027 - 181ms/epoch - 2ms/step
# Epoch 24/100
# 113/113 - 0s - loss: 0.0027 - 183ms/epoch - 2ms/step
# Epoch 25/100
# 113/113 - 0s - loss: 0.0028 - 188ms/epoch - 2ms/step
# Epoch 26/100
# 113/113 - 0s - loss: 0.0027 - 250ms/epoch - 2ms/step
# Epoch 27/100
# 113/113 - 0s - loss: 0.0027 - 257ms/epoch - 2ms/step
# Epoch 28/100
# 113/113 - 0s - loss: 0.0028 - 240ms/epoch - 2ms/step
# Epoch 29/100
# 113/113 - 0s - loss: 0.0028 - 255ms/epoch - 2ms/step
# Epoch 30/100
# 113/113 - 0s - loss: 0.0027 - 255ms/epoch - 2ms/step
# Epoch 31/100
# 113/113 - 0s - loss: 0.0027 - 258ms/epoch - 2ms/step
# Epoch 32/100
# 113/113 - 0s - loss: 0.0028 - 279ms/epoch - 2ms/step
# Epoch 33/100
# 113/113 - 0s - loss: 0.0028 - 276ms/epoch - 2ms/step
# Epoch 34/100
# 113/113 - 0s - loss: 0.0027 - 238ms/epoch - 2ms/step
# Epoch 35/100
# 113/113 - 0s - loss: 0.0027 - 183ms/epoch - 2ms/step
# Epoch 36/100
# 113/113 - 0s - loss: 0.0027 - 195ms/epoch - 2ms/step
# Epoch 37/100
# 113/113 - 0s - loss: 0.0028 - 183ms/epoch - 2ms/step
# Epoch 38/100
# 113/113 - 0s - loss: 0.0027 - 198ms/epoch - 2ms/step
# Epoch 39/100
# 113/113 - 0s - loss: 0.0028 - 178ms/epoch - 2ms/step
# Epoch 40/100
# 113/113 - 0s - loss: 0.0027 - 177ms/epoch - 2ms/step
# Epoch 41/100
# 113/113 - 0s - loss: 0.0027 - 191ms/epoch - 2ms/step
# Epoch 42/100
# 113/113 - 0s - loss: 0.0028 - 174ms/epoch - 2ms/step
# Epoch 43/100
# 113/113 - 0s - loss: 0.0026 - 187ms/epoch - 2ms/step
# Epoch 44/100
# 113/113 - 0s - loss: 0.0028 - 175ms/epoch - 2ms/step
# Epoch 45/100
# 113/113 - 0s - loss: 0.0027 - 178ms/epoch - 2ms/step
# Epoch 46/100
# 113/113 - 0s - loss: 0.0027 - 181ms/epoch - 2ms/step
# Epoch 47/100
# 113/113 - 0s - loss: 0.0027 - 176ms/epoch - 2ms/step
# Epoch 48/100
# 113/113 - 0s - loss: 0.0027 - 181ms/epoch - 2ms/step
# Epoch 49/100
# 113/113 - 0s - loss: 0.0027 - 190ms/epoch - 2ms/step
# Epoch 50/100
# 113/113 - 0s - loss: 0.0027 - 179ms/epoch - 2ms/step
# Epoch 51/100
# 113/113 - 0s - loss: 0.0028 - 184ms/epoch - 2ms/step
# Epoch 52/100
# 113/113 - 0s - loss: 0.0027 - 175ms/epoch - 2ms/step
# Epoch 53/100
# 113/113 - 0s - loss: 0.0028 - 181ms/epoch - 2ms/step
# Epoch 54/100
# 113/113 - 0s - loss: 0.0027 - 184ms/epoch - 2ms/step
# Epoch 55/100
# 113/113 - 0s - loss: 0.0028 - 184ms/epoch - 2ms/step
# Epoch 56/100
# 113/113 - 0s - loss: 0.0027 - 179ms/epoch - 2ms/step
# Epoch 57/100
# 113/113 - 0s - loss: 0.0027 - 182ms/epoch - 2ms/step
# Epoch 58/100
# 113/113 - 0s - loss: 0.0026 - 176ms/epoch - 2ms/step
# Epoch 59/100
# 113/113 - 0s - loss: 0.0027 - 180ms/epoch - 2ms/step
# Epoch 60/100
# 113/113 - 0s - loss: 0.0028 - 191ms/epoch - 2ms/step
# Epoch 61/100
# 113/113 - 0s - loss: 0.0027 - 183ms/epoch - 2ms/step
# Epoch 62/100
# 113/113 - 0s - loss: 0.0028 - 180ms/epoch - 2ms/step
# Epoch 63/100
# 113/113 - 0s - loss: 0.0025 - 175ms/epoch - 2ms/step
# Epoch 64/100
# 113/113 - 0s - loss: 0.0027 - 182ms/epoch - 2ms/step
# Epoch 65/100
# 113/113 - 0s - loss: 0.0027 - 179ms/epoch - 2ms/step
# Epoch 66/100
# 113/113 - 0s - loss: 0.0026 - 188ms/epoch - 2ms/step
# Epoch 67/100
# 113/113 - 0s - loss: 0.0027 - 180ms/epoch - 2ms/step
# Epoch 68/100
# 113/113 - 0s - loss: 0.0026 - 182ms/epoch - 2ms/step
# Epoch 69/100
# 113/113 - 0s - loss: 0.0028 - 178ms/epoch - 2ms/step
# Epoch 70/100
# 113/113 - 0s - loss: 0.0027 - 177ms/epoch - 2ms/step
# Epoch 71/100
# 113/113 - 0s - loss: 0.0027 - 196ms/epoch - 2ms/step
# Epoch 72/100
# 113/113 - 0s - loss: 0.0027 - 179ms/epoch - 2ms/step
# Epoch 73/100
# 113/113 - 0s - loss: 0.0027 - 183ms/epoch - 2ms/step
# Epoch 74/100
# 113/113 - 0s - loss: 0.0027 - 177ms/epoch - 2ms/step
# Epoch 75/100
# 113/113 - 0s - loss: 0.0027 - 178ms/epoch - 2ms/step
# Epoch 76/100
# 113/113 - 0s - loss: 0.0027 - 179ms/epoch - 2ms/step
# Epoch 77/100
# 113/113 - 0s - loss: 0.0027 - 186ms/epoch - 2ms/step
# Epoch 78/100
# 113/113 - 0s - loss: 0.0027 - 179ms/epoch - 2ms/step
# Epoch 79/100
# 113/113 - 0s - loss: 0.0027 - 180ms/epoch - 2ms/step
# Epoch 80/100
# 113/113 - 0s - loss: 0.0027 - 179ms/epoch - 2ms/step
# Epoch 81/100
# 113/113 - 0s - loss: 0.0027 - 174ms/epoch - 2ms/step
# Epoch 82/100
# 113/113 - 0s - loss: 0.0026 - 189ms/epoch - 2ms/step
# Epoch 83/100
# 113/113 - 0s - loss: 0.0027 - 182ms/epoch - 2ms/step
# Epoch 84/100
# 113/113 - 0s - loss: 0.0028 - 180ms/epoch - 2ms/step
# Epoch 85/100
# 113/113 - 0s - loss: 0.0027 - 183ms/epoch - 2ms/step
# Epoch 86/100
# 113/113 - 0s - loss: 0.0027 - 181ms/epoch - 2ms/step
# Epoch 87/100
# 113/113 - 0s - loss: 0.0027 - 185ms/epoch - 2ms/step
# Epoch 88/100
# 113/113 - 0s - loss: 0.0027 - 217ms/epoch - 2ms/step
# Epoch 89/100
# 113/113 - 0s - loss: 0.0026 - 274ms/epoch - 2ms/step
# Epoch 90/100
# 113/113 - 0s - loss: 0.0027 - 261ms/epoch - 2ms/step
# Epoch 91/100
# 113/113 - 0s - loss: 0.0027 - 265ms/epoch - 2ms/step
# Epoch 92/100
# 113/113 - 0s - loss: 0.0027 - 263ms/epoch - 2ms/step
# Epoch 93/100
# 113/113 - 0s - loss: 0.0026 - 246ms/epoch - 2ms/step
# Epoch 94/100
# 113/113 - 0s - loss: 0.0028 - 263ms/epoch - 2ms/step
# Epoch 95/100
# 113/113 - 0s - loss: 0.0027 - 272ms/epoch - 2ms/step
# Epoch 96/100
# 113/113 - 0s - loss: 0.0027 - 244ms/epoch - 2ms/step
# Epoch 97/100
# 113/113 - 0s - loss: 0.0027 - 180ms/epoch - 2ms/step
# Epoch 98/100
# 113/113 - 0s - loss: 0.0027 - 180ms/epoch - 2ms/step
# Epoch 99/100
# 113/113 - 0s - loss: 0.0026 - 178ms/epoch - 2ms/step
# Epoch 100/100
# 113/113 - 0s - loss: 0.0027 - 175ms/epoch - 2ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 38ms/step
# Train Score: 26.25 RMSE
# Test Score: 51.10 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# To refer to the source of the code, please visit this website:
#
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
